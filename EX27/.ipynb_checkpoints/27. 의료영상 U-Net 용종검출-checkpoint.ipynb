# %%
# 필요 라이브러리 로딩
from __future__ import absolute_import, division
from __future__ import print_function, unicode_literals

import os
import time
import shutil
import functools

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
mpl.rcParams['axes.grid'] = False
mpl.rcParams['figure.figsize'] = (12,12)

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.image as mpimg
import pandas as pd
from PIL import Image
from IPython.display import clear_output

import tensorflow as tf
import tensorflow_addons as tfa
print(tf.__version__)

from tensorflow.keras import layers
from tensorflow.keras import losses
from tensorflow.keras import models
# Out:
# 2.2.0

# %%
DATASET_PATH=os.path.join(os.getenv('HOME'),'aiffel/medical')

if not os.path.isdir(DATASET_PATH):
    os.makedirs(DATASET_PATH)
file_path = os.path.join(DATASET_PATH, 'sd_train.zip')
if not os.path.exists(file_path):
    import urllib.request
    u = urllib.request.urlopen(url='https://aiffelstaticprd.blob.core.windows.net/media/documents/sd_train.zip')
    data = u.read()
    u.close()

    with open('sd_train.zip', "wb") as f :
        f.write(data)
        print('Data has been downloaded')

    shutil.move(os.path.join('sd_train.zip'), os.path.join(DATASET_PATH))


import zipfile
zip_ref = zipfile.ZipFile(file_path, 'r')
zip_ref.extractall(DATASET_PATH)
zip_ref.close()
print('Data has been extracted.')
# Out:
# Data has been extracted.

# %%
img_dir = os.path.join(DATASET_PATH, "train")
label_dir = os.path.join(DATASET_PATH, "train_labels")

# %%
x_train_filenames = [os.path.join(img_dir, filename) for filename in os.listdir(img_dir)]
x_train_filenames.sort()
y_train_filenames = [os.path.join(label_dir, filename) for filename in os.listdir(label_dir)]
y_train_filenames.sort()

# %%
x_train_filenames, x_test_filenames, y_train_filenames, y_test_filenames = \
                    train_test_split(x_train_filenames, y_train_filenames, test_size=0.2)

# %%
num_train_examples = len(x_train_filenames)
num_test_examples = len(x_test_filenames)

print("Number of training examples: {}".format(num_train_examples))
print("Number of test examples: {}".format(num_test_examples))
# Out:
# Number of training examples: 480
# Number of test examples: 120

# %%
display_num = 5

r_choices = np.random.choice(num_train_examples, display_num)

plt.figure(figsize=(10, 15))
for i in range(0, display_num * 2, 2):
    img_num = r_choices[i // 2]
    x_pathname = x_train_filenames[img_num]
    y_pathname = y_train_filenames[img_num]

    plt.subplot(display_num, 2, i + 1)
    plt.imshow(Image.open(x_pathname))
    plt.title("Original Image")

    example_labels = Image.open(y_pathname)
    label_vals = np.unique(example_labels)

    plt.subplot(display_num, 2, i + 2)
    plt.imshow(example_labels)
    plt.title("Masked Image")
    
plt.suptitle("Examples of Images and their Masks")
plt.show()

# %%
# Set hyperparameters

image_size = 256
img_shape = (image_size, image_size, 3)
batch_size = 2
max_epochs = 50

# %%
def _process_pathnames(fname, label_path):
    # We map this function onto each pathname pair
    img_str = tf.io.read_file(fname)
    img = tf.image.decode_bmp(img_str, channels=3) # RGB

    label_img_str = tf.io.read_file(label_path)
    label_img = tf.image.decode_bmp(label_img_str, channels=1) # BMP 0,1

    resize = [image_size, image_size]
    img = tf.image.resize(img, resize)
    label_img = tf.image.resize(label_img, resize)

    scale = 1 / 255.
    img = tf.cast(img, dtype=tf.float32) * scale
    label_img = tf.cast(label_img, dtype=tf.float32) * scale

    return img, label_img

# %%
def shift_img(output_img, label_img, width_shift_range, height_shift_range):
    """This fn will perform the horizontal or vertical shift"""
    if width_shift_range or height_shift_range:
        if width_shift_range:
                width_shift_range = tf.random.uniform([],
                                                  -width_shift_range * img_shape[1],
                                                  width_shift_range * img_shape[1])
        if height_shift_range:
                height_shift_range = tf.random.uniform([],
                                                   -height_shift_range * img_shape[0],
                                                   height_shift_range * img_shape[0])
        output_img = tfa.image.translate(output_img,
                                         [width_shift_range, height_shift_range])
        label_img = tfa.image.translate(label_img,
                                        [width_shift_range, height_shift_range])
    return output_img, label_img

# %%
def flip_img(horizontal_flip, tr_img, label_img):
    if horizontal_flip:
        flip_prob = tf.random.uniform([], 0.0, 1.0)
        tr_img, label_img = tf.cond(tf.less(flip_prob, 0.5),
                                lambda: (tf.image.flip_left_right(tr_img), tf.image.flip_left_right(label_img)),
                                lambda: (tr_img, label_img))
    return tr_img, label_img

# %%
def _augment(img,
             label_img,
             resize=None,  # Resize the image to some size e.g. [256, 256]
             scale=1,  # Scale image e.g. 1 / 255.
             hue_delta=0.,  # Adjust the hue of an RGB image by random factor
             horizontal_flip=True,  # Random left right flip,
             width_shift_range=0.05,  # Randomly translate the image horizontally
             height_shift_range=0.05):  # Randomly translate the image vertically 
    if resize is not None:
        # Resize both images
        label_img = tf.image.resize(label_img, resize)
        img = tf.image.resize(img, resize)
  
    if hue_delta:
        img = tf.image.random_hue(img, hue_delta)
  
    img, label_img = flip_img(horizontal_flip, img, label_img)
    img, label_img = shift_img(img, label_img, width_shift_range, height_shift_range)
    label_img = tf.cast(label_img, dtype=tf.float32) * scale
    img = tf.cast(img, dtype=tf.float32) * scale
    return img, label_img

# %%
def get_baseline_dataset(filenames,
                         labels,
                         preproc_fn=functools.partial(_augment),
                         threads=4,
                         batch_size=batch_size,
                         is_train=True):
    num_x = len(filenames)
    # Create a dataset from the filenames and labels
    dataset = tf.data.Dataset.from_tensor_slices((filenames, labels))
    # Map our preprocessing function to every element in our dataset, taking
    # advantage of multithreading
    dataset = dataset.map(_process_pathnames, num_parallel_calls=threads)

    if is_train:# 학습을 진행할시에만 위에 augment를 진행합니다.
        #if preproc_fn.keywords is not None and 'resize' not in preproc_fn.keywords:
        #  assert batch_size == 1, "Batching images must be of the same size"
        dataset = dataset.map(preproc_fn, num_parallel_calls=threads)
        dataset = dataset.shuffle(num_x * 10)

    dataset = dataset.batch(batch_size)
    return dataset

# %%
train_dataset = get_baseline_dataset(x_train_filenames, # 학습 데이터
                                     y_train_filenames) # 정답 데이터
train_dataset = train_dataset.repeat()
test_dataset = get_baseline_dataset(x_test_filenames,
                                    y_test_filenames,
                                    is_train=False)
train_dataset
# Out:
# <RepeatDataset shapes: ((None, 256, 256, 3), (None, 256, 256, 1)), types: (tf.float32, tf.float32)>

# %%
for images, labels in train_dataset.take(1):
    # Running next element in our graph will produce a batch of images
    plt.figure(figsize=(10, 10))
    img = images[0]

    plt.subplot(1, 2, 1)
    plt.imshow(img)

    plt.subplot(1, 2, 2)
    plt.imshow(labels[0, :, :, 0])
    plt.show()

# %%
# inputs: [batch_size, 256, 256, 3]
encoder = tf.keras.Sequential(name='encoder')

# conv-batchnorm-activation-maxpool
encoder.add(layers.Conv2D(64, (3, 3), padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu'))
encoder.add(layers.Conv2D(64, (3, 3), strides=2, padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu')) # conv1: [batch_size, 128, 128, 64]

encoder.add(layers.Conv2D(128, (3, 3), padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu'))
encoder.add(layers.Conv2D(128, (3, 3), strides=2, padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu')) # conv2: [batch_size, 64, 64, 128]

encoder.add(layers.Conv2D(256, (3, 3), padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu'))
encoder.add(layers.Conv2D(256, (3, 3), strides=2, padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu')) # conv3: [batch_size, 32, 32, 256]

encoder.add(layers.Conv2D(512, (3, 3), padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu'))
encoder.add(layers.Conv2D(512, (3, 3), strides=2, padding='same'))
encoder.add(layers.BatchNormalization())
encoder.add(layers.Activation('relu')) # conv4-outputs: [batch_size, 16, 16, 512]

# %%
# Encoder 제대로 만들어졌는지 확인

bottleneck = encoder(tf.random.normal([batch_size, 256, 256, 3]))
print(bottleneck.shape)   # (batch_size, 16, 16, 512) 이 나오는지 확인
# Out:
# (2, 16, 16, 512)

# %%
# inputs: [batch_size, 16, 16, 512]
decoder = tf.keras.Sequential(name='decoder')

# conv_transpose-batchnorm-activation
decoder.add(layers.Conv2DTranspose(256, (3, 3), strides=2, padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu')) # conv_transpose1: [batch_size, 32, 32, 256]
decoder.add(layers.Conv2D(256, (3, 3), padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu'))

decoder.add(layers.Conv2DTranspose(128, (3, 3), strides=2, padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu')) # conv_transpose2: [batch_size, 64, 64, 128]
decoder.add(layers.Conv2D(128, (3, 3), padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu'))

decoder.add(layers.Conv2DTranspose(64, (3, 3), strides=2, padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu')) # conv_transpose3: [batch_size, 128, 128, 64]
decoder.add(layers.Conv2D(64, (3, 3), padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu'))

decoder.add(layers.Conv2DTranspose(32, (3, 3), strides=2, padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu')) # conv transpose4-outputs: [batch_size, 256, 256, 32]
decoder.add(layers.Conv2D(32, (3, 3), padding='same'))
decoder.add(layers.BatchNormalization())
decoder.add(layers.Activation('relu'))

decoder.add(layers.Conv2DTranspose(1, 1, strides=1, padding='same', activation='sigmoid'))

# %%
# decoder 제대로 만들어졌는지 확인

predictions = decoder(bottleneck)
print(predictions.shape)    # (batch_size, 256, 256, 1) 이 나오는지 확인
# Out:
# (2, 256, 256, 1)

# %%
ed_model = tf.keras.Sequential()

ed_model.add(encoder)
ed_model.add(decoder)

# %%
class Conv(tf.keras.Model):
    def __init__(self, num_filters, kernel_size):
        super(Conv, self).__init__()
        self.conv = layers.Conv2D(num_filters, kernel_size, padding='same')
        self.bn = layers.BatchNormalization()

    def call(self, inputs, training=True):
        x = self.conv(inputs)
        x = self.bn(x, training=training)
        x = layers.ReLU()(x)

        return x

# %%
class ConvBlock(tf.keras.Model):
    def __init__(self, num_filters):
        super(ConvBlock, self).__init__()
        self.conv1 = Conv(num_filters, 3)
        self.conv2 = Conv(num_filters * 2, 3)

    def call(self, inputs, training=True):
        encoder = self.conv1(inputs, training=training)
        encoder = self.conv2(encoder, training=training)

        return encoder

class ConvBlock_R(tf.keras.Model):
    def __init__(self, num_filters):
        super(ConvBlock_R, self).__init__()
        self.conv1 = Conv(num_filters, 3)
        self.conv2 = Conv(num_filters, 3)

    def call(self, inputs, training=True):
        decoder = self.conv1(inputs, training=training)
        decoder = self.conv2(decoder, training=training)

        return decoder


class EncoderBlock(tf.keras.Model):
    def __init__(self, num_filters):
        super(EncoderBlock, self).__init__()
        self.conv_block = ConvBlock(num_filters)
        self.encoder_pool = layers.MaxPool2D()

    def call(self, inputs, training=True):
        encoder = self.conv_block(inputs, training=training)
        encoder_pool = self.encoder_pool(encoder)

        return encoder_pool, encoder


class DecoderBlock(tf.keras.Model):
    def __init__(self, num_filters):
        super(DecoderBlock, self).__init__()
        self.convT = layers.Conv2DTranspose(num_filters, 3, strides=2, padding='same')
        self.bn = layers.BatchNormalization()
        self.conv_block_r = ConvBlock_R(num_filters)

    def call(self, input_tensor, concat_tensor, training=True):
        decoder = self.convT(input_tensor)            
        decoder = self.bn(decoder, training=training)
        decoder = layers.ReLU()(decoder)
        decoder = tf.concat([decoder, concat_tensor], axis=-1)
        decoder = self.conv_block_r(decoder, training=training)

        return decoder

# %%
class UNet(tf.keras.Model):
    def __init__(self):
        super(UNet, self).__init__()
        self.encoder_block1 = EncoderBlock(64)
        self.encoder_block2 = EncoderBlock(128)
        self.encoder_block3 = EncoderBlock(256)
        self.encoder_block4 = EncoderBlock(512)

        self.center = ConvBlock(1024)

        self.decoder_block4 = DecoderBlock(512)
        self.decoder_block3 = DecoderBlock(256)
        self.decoder_block2 = DecoderBlock(128)
        self.decoder_block1 = DecoderBlock(64)

        self.output_conv = layers.Conv2D(1, 1, activation='sigmoid')

    def call(self, inputs, training=True):
        encoder1_pool, encoder1 = self.encoder_block1(inputs)
        encoder2_pool, encoder2 = self.encoder_block2(encoder1_pool)
        encoder3_pool, encoder3 = self.encoder_block3(encoder2_pool)
        encoder4_pool, encoder4 = self.encoder_block4(encoder3_pool)

        center = self.center(encoder4_pool)

        decoder4 = self.decoder_block4(center, encoder4)
        decoder3 = self.decoder_block3(decoder4, encoder3)
        decoder2 = self.decoder_block2(decoder3, encoder2)
        decoder1 = self.decoder_block1(decoder2, encoder1)

        outputs = self.output_conv(decoder1)

        return outputs

# %%
unet_model = UNet()

# %%
def dice_coeff(y_true, y_pred):
    smooth = 1e-10
    # Flatten
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    score = (2. * intersection + smooth) / (tf.reduce_sum(tf.square(y_true_f)) + \
                                            tf.reduce_sum(tf.square(y_pred_f)) + smooth)

    return score

# %%
def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss

# %%
def bce_dice_loss(y_true, y_pred):
    loss = tf.reduce_mean(losses.binary_crossentropy(y_true, y_pred)) + \
          dice_loss(y_true, y_pred)
    return loss

# %%
optimizer = tf.keras.optimizers.Adam() # 기본 Learning rate 사용

# %%
print('select the U-Net model')
model = unet_model
checkpoint_dir =os.path.join(DATASET_PATH,'train_ckpt/unet_model')
# Out:
# select the U-Net model

# %%
model.compile(optimizer=optimizer, loss=bce_dice_loss, metrics=[dice_loss])
predictions = model(tf.random.normal([batch_size, image_size, image_size, 3]))
print(predictions.shape)
# Out:
# (2, 256, 256, 1)

# %%
model.summary()
# Out:
# Model: "u_net"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_block (EncoderBlock) multiple                  76416
# _________________________________________________________________
# encoder_block_1 (EncoderBloc multiple                  444288
# _________________________________________________________________
# encoder_block_2 (EncoderBloc multiple                  1773312
# _________________________________________________________________
# encoder_block_3 (EncoderBloc multiple                  7085568
# _________________________________________________________________
# conv_block_4 (ConvBlock)     multiple                  28326912
# _________________________________________________________________
# decoder_block (DecoderBlock) multiple                  18882048
# _________________________________________________________________
# decoder_block_1 (DecoderBloc multiple                  3542784
# _________________________________________________________________
# decoder_block_2 (DecoderBloc multiple                  886656
# _________________________________________________________________
# decoder_block_3 (DecoderBloc multiple                  222144
# _________________________________________________________________
# conv2d_30 (Conv2D)           multiple                  65
# =================================================================
# Total params: 61,240,193
# Trainable params: 61,222,529
# Non-trainable params: 17,664
# _________________________________________________________________

# %%
if not os.path.isdir(checkpoint_dir):
    os.makedirs(checkpoint_dir)

cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=0)

# %%
cos_decay = tf.keras.experimental.CosineDecay(1e-3, 
                                              max_epochs)
lr_callback = tf.keras.callbacks.LearningRateScheduler(cos_decay, verbose=1)

# %%
## Define print function
def print_images():
    for test_images, test_labels in test_dataset.take(1):
        predictions = model(test_images, training=False)

        plt.figure(figsize=(10, 20))
        plt.subplot(1, 3, 1)
        plt.imshow(test_images[0,: , :, :])
        plt.title("Input image")

        plt.subplot(1, 3, 2)
        plt.imshow(test_labels[0, :, :, 0])
        plt.title("Actual Mask")

        plt.subplot(1, 3, 3)
        plt.imshow(predictions[0, :, :, 0])
        plt.title("Predicted Mask")
        plt.show()

# %%
history = model.fit(train_dataset,
                    epochs=max_epochs,    # 50
                    steps_per_epoch=num_train_examples//batch_size,
                    validation_data=test_dataset,
                    validation_steps=num_test_examples//batch_size,
                    callbacks=[cp_callback, lr_callback]
                    )
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to tf.Tensor(0.001, shape=(), dtype=float32).
# Epoch 1/50
# 240/240 [==============================] - 47s 197ms/step - loss: 0.9470 - dice_loss: 0.7160 - val_loss: 1.0681 - val_dice_loss: 0.8791 - lr: 0.0010
#
# Epoch 00002: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009990134, shape=(), dtype=float32).
# Epoch 2/50
# 240/240 [==============================] - 52s 216ms/step - loss: 0.8956 - dice_loss: 0.6989 - val_loss: 0.9359 - val_dice_loss: 0.7422 - lr: 9.9901e-04
#
# Epoch 00003: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009960574, shape=(), dtype=float32).
# Epoch 3/50
# 240/240 [==============================] - 46s 191ms/step - loss: 0.8720 - dice_loss: 0.6794 - val_loss: 22.7734 - val_dice_loss: 0.8607 - lr: 9.9606e-04
#
# Epoch 00004: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009911436, shape=(), dtype=float32).
# Epoch 4/50
# 240/240 [==============================] - 49s 203ms/step - loss: 0.7998 - dice_loss: 0.6211 - val_loss: 1.0729 - val_dice_loss: 0.7560 - lr: 9.9114e-04
#
# Epoch 00005: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009842915, shape=(), dtype=float32).
# Epoch 5/50
# 240/240 [==============================] - 47s 197ms/step - loss: 0.7584 - dice_loss: 0.5896 - val_loss: 1.1032 - val_dice_loss: 0.8883 - lr: 9.8429e-04
#
# Epoch 00006: LearningRateScheduler reducing learning rate to tf.Tensor(0.00097552827, shape=(), dtype=float32).
# Epoch 6/50
# 240/240 [==============================] -
- lr: 2.3209e-04
#
# Epoch 00036: LearningRateScheduler reducing learning rate to tf.Tensor(0.00020610739, shape=(), dtype=float32).
# Epoch 36/50
# 240/240 [==============================] - 10s 44ms/step - loss: 0.0815 - dice_loss: 0.0613 - val_loss: 0.1254 - val_dice_loss: 0.0957 - lr: 2.0611e-04
#
# Epoch 00037: LearningRateScheduler reducing learning rate to tf.Tensor(0.00018128792, shape=(), dtype=float32).
# Epoch 37/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.0742 - dice_loss: 0.0552 - val_loss: 0.1473 - val_dice_loss: 0.1123 - lr: 1.8129e-04
#
# Epoch 00038: LearningRateScheduler reducing learning rate to tf.Tensor(0.00015772645, shape=(), dtype=float32).
# Epoch 38/50
# 240/240 [==============================] - 10s 43ms/step - loss: 0.0791 - dice_loss: 0.0597 - val_loss: 0.1184 - val_dice_loss: 0.0899 - lr: 1.5773e-04
#
# Epoch 00039: LearningRateScheduler reducing learning rate to tf.Tensor(0.0001355157, shape=(), dtype=float32).
# Epoch 39/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0762 - dice_loss: 0.0574 - val_loss: 0.1381 - val_dice_loss: 0.1064 - lr: 1.3552e-04
#
# Epoch 00040: LearningRateScheduler reducing learning rate to tf.Tensor(0.00011474339, shape=(), dtype=float32).
# Epoch 40/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0732 - dice_loss: 0.0549 - val_loss: 0.1374 - val_dice_loss: 0.1055 - lr: 1.1474e-04
#
# Epoch 00041: LearningRateScheduler reducing learning rate to tf.Tensor(9.54915e-05, shape=(), dtype=float32).
# Epoch 41/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0703 - dice_loss: 0.0527 - val_loss: 0.1294 - val_dice_loss: 0.0989 - lr: 9.5492e-05
#
# Epoch 00042: LearningRateScheduler reducing learning rate to tf.Tensor(7.783601e-05, shape=(), dtype=float32).
# Epoch 42/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0683 - dice_loss: 0.0512 - val_loss: 0.1227 - val_dice_loss: 0.0935 - lr: 7.7836e-05
#
# Epoch 00043: LearningRateScheduler reducing learning rate to tf.Tensor(6.184671e-05, shape=(), dtype=float32).
# Epoch 43/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0698 - dice_loss: 0.0522 - val_loss: 0.1201 - val_dice_loss: 0.0915 - lr: 6.1847e-05
#
# Epoch 00044: LearningRateScheduler reducing learning rate to tf.Tensor(4.7586444e-05, shape=(), dtype=float32).
# Epoch 44/50
# 240/240 [==============================] - 10s 43ms/step - loss: 0.0714 - dice_loss: 0.0538 - val_loss: 0.1156 - val_dice_loss: 0.0879 - lr: 4.7586e-05
#
# Epoch 00045: LearningRateScheduler reducing learning rate to tf.Tensor(3.5111727e-05, shape=(), dtype=float32).
# Epoch 45/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0700 - dice_loss: 0.0527 - val_loss: 0.1256 - val_dice_loss: 0.0958 - lr: 3.5112e-05
#
# Epoch 00046: LearningRateScheduler reducing learning rate to tf.Tensor(2.4471761e-05, shape=(), dtype=float32).
# Epoch 46/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0663 - dice_loss: 0.0497 - val_loss: 0.1171 - val_dice_loss: 0.0889 - lr: 2.4472e-05
#
# Epoch 00047: LearningRateScheduler reducing learning rate to tf.Tensor(1.5708387e-05, shape=(), dtype=float32).
# Epoch 47/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0655 - dice_loss: 0.0488 - val_loss: 0.1178 - val_dice_loss: 0.0898 - lr: 1.5708e-05
#
# Epoch 00048: LearningRateScheduler reducing learning rate to tf.Tensor(8.856387e-06, shape=(), dtype=float32).
# Epoch 48/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0653 - dice_loss: 0.0486 - val_loss: 0.1191 - val_dice_loss: 0.0907 - lr: 8.8564e-06
#
# Epoch 00049: LearningRateScheduler reducing learning rate to tf.Tensor(3.9426386e-06, shape=(), dtype=float32).
# Epoch 49/50
# 240/240 [==============================] - 10s 42ms/step - loss: 0.0655 - dice_loss: 0.0490 - val_loss: 0.1184 - val_dice_loss: 0.0902 - lr: 3.9426e-06
#
# Epoch 00050: LearningRateScheduler reducing learning rate to tf.Tensor(9.866358e-07, shape=(), dtype=float32).
# Epoch 50/50
# 240/240 [==============================] - 10s 41ms/step - loss: 0.0644 - dice_loss: 0.0479 - val_loss: 0.1192 - val_dice_loss: 0.0908 - lr: 9.8664e-07

# %%
dice_loss = history.history['dice_loss']
loss = history.history['loss']
val_dice_loss = history.history['val_dice_loss']
val_loss = history.history['val_loss']

epochs_range = range(max_epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, loss, label='Loss')
plt.plot(epochs_range, dice_loss, label='Dice Loss')
plt.legend(loc='upper right')
plt.title('Train Loss')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, val_loss, label='Val Loss')
plt.plot(epochs_range, val_dice_loss, label='Val Dice Loss')
plt.legend(loc='upper right')
plt.title('Valid Loss')
plt.show()

# %%
print_images()

# %%
# restoring the latest checkpoint in checkpoint_dir
model.load_weights(checkpoint_dir)

# %%
def mean_iou(y_true, y_pred, num_classes=2):
    # Flatten  
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])

    y_true_f = tf.cast(tf.round(y_true_f), dtype=tf.int32).numpy()
    y_pred_f = tf.cast(tf.round(y_pred_f), dtype=tf.int32).numpy()

    # calculate confusion matrix
    labels = list(range(num_classes))
    current = confusion_matrix(y_true_f, y_pred_f, labels=labels)

    # compute mean iou
    intersection = np.diag(current)
    ground_truth_set = current.sum(axis=1)
    predicted_set = current.sum(axis=0)
    union = ground_truth_set + predicted_set - intersection

    IoU = intersection / union.astype(np.float32)
    return np.mean(IoU)

# %%
mean = []

for images, labels in test_dataset:
    predictions = model(images, training=False)
    m = mean_iou(labels, predictions)
    mean.append(m)

mean = np.array(mean)
mean = np.mean(mean)
print("mean_iou: {}".format(mean))
# Out:
# mean_iou: 0.8988563014081851

# %% [markdown]
# # pretrained UNet

# %%
class Vgg16UNet(tf.keras.Model):
    def __init__(self):
        super(Vgg16UNet, self).__init__()
        self.vgg16 = tf.keras.applications.VGG16(input_shape=img_shape,
                                         include_top=False,
                                         weights='imagenet')
        layer_outputs = [layer.output for layer in self.vgg16.layers]
        self.vgg16_act = models.Model(inputs=self.vgg16.input, 
                                      outputs=[layer_outputs[2], 
                                               layer_outputs[5], 
                                               layer_outputs[9], 
                                               layer_outputs[13], 
                                               layer_outputs[17]])


        self.center = ConvBlock(1024)

        self.decoder_block4 = DecoderBlock(512)
        self.decoder_block3 = DecoderBlock(256)
        self.decoder_block2 = DecoderBlock(128)
        self.decoder_block1 = DecoderBlock(64)

        self.output_conv = layers.Conv2D(1, 1, activation='sigmoid')

    def call(self, inputs, training=True):

        encoder1, encoder2, encoder3, encoder4, center = self.vgg16_act(inputs) 

        decoder4 = self.decoder_block4(center, encoder4)
        decoder3 = self.decoder_block3(decoder4, encoder3)
        decoder2 = self.decoder_block2(decoder3, encoder2)
        decoder1 = self.decoder_block1(decoder2, encoder1)
        
        outputs = self.output_conv(decoder1)

        return outputs

# %%
model = Vgg16UNet()

# %%
checkpoint_dir =os.path.join(DATASET_PATH,'train_ckpt/ptUnet_model')

# %%
def dice_loss(y_true, y_pred):
    loss = 1 - dice_coeff(y_true, y_pred)
    return loss

def bce_dice_loss(y_true, y_pred):
    loss = tf.reduce_mean(losses.binary_crossentropy(y_true, y_pred)) + \
          dice_loss(y_true, y_pred)
    return loss

model.compile(optimizer=optimizer, loss=bce_dice_loss, metrics=[dice_loss])
predictions = model(tf.random.normal([batch_size, image_size, image_size, 3]))
print(predictions.shape)

train_dataset = get_baseline_dataset(x_train_filenames, # 학습 데이터
                                     y_train_filenames) # 정답 데이터
train_dataset = train_dataset.repeat()
test_dataset = get_baseline_dataset(x_test_filenames,
                                    y_test_filenames,
                                    is_train=False)
if not os.path.isdir(checkpoint_dir):
    os.makedirs(checkpoint_dir)

cp_callback = tf.keras.callbacks.ModelCheckpoint(checkpoint_dir,
                                                 save_weights_only=True,
                                                 monitor='val_loss',
                                                 mode='auto',
                                                 save_best_only=True,
                                                 verbose=0)

cos_decay = tf.keras.experimental.CosineDecay(1e-3, 
                                              max_epochs)
lr_callback = tf.keras.callbacks.LearningRateScheduler(cos_decay, verbose=1)
# Out:
# (2, 256, 256, 1)

# %%
history = model.fit(train_dataset,
                    epochs=max_epochs,    # 50
                    steps_per_epoch=num_train_examples//batch_size,
                    validation_data=test_dataset,
                    validation_steps=num_test_examples//batch_size,
                    callbacks=[cp_callback, lr_callback]
                    )
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to tf.Tensor(0.001, shape=(), dtype=float32).
# Epoch 1/50
# 240/240 [==============================] - 31s 129ms/step - loss: 0.9260 - dice_loss: 0.7070 - val_loss: 1.0634 - val_dice_loss: 0.7336 - lr: 0.0010
#
# Epoch 00002: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009990134, shape=(), dtype=float32).
# Epoch 2/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.8654 - dice_loss: 0.6759 - val_loss: 1.0968 - val_dice_loss: 0.8962 - lr: 9.9901e-04
#
# Epoch 00003: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009960574, shape=(), dtype=float32).
# Epoch 3/50
# 240/240 [==============================] - 30s 127ms/step - loss: 0.8428 - dice_loss: 0.6585 - val_loss: 0.9055 - val_dice_loss: 0.7300 - lr: 9.9606e-04
#
# Epoch 00004: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009911436, shape=(), dtype=float32).
# Epoch 4/50
# 240/240 [==============================] - 29s 121ms/step - loss: 0.7948 - dice_loss: 0.6188 - val_loss: 1.1688 - val_dice_loss: 0.9572 - lr: 9.9114e-04
#
# Epoch 00005: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009842915, shape=(), dtype=float32).
# Epoch 5/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.7228 - dice_loss: 0.5620 - val_loss: 0.9225 - val_dice_loss: 0.7451 - lr: 9.8429e-04
#
# Epoch 00006: LearningRateScheduler reducing learning rate to tf.Tensor(0.00097552827, shape=(), dtype=float32).
# Epoch 6/50
# 240/240 [==============================] - 29s 122ms/step - loss: 0.6917 - dice_loss: 0.5377 - val_loss: 0.8417 - val_dice_loss: 0.6780 - lr: 9.7553e-04
#
# Epoch 00007: LearningRateScheduler reducing learning rate to tf.Tensor(0.00096488826, shape=(), dtype=float32).
# Epoch 7/50
# 240/240 [==============================] - 29s 122ms/step - loss: 0.6513 - dice_loss: 0.5050 - val_loss: 0.7816 - val_dice_loss: 0.5922 - lr: 9.6489e-04
#
# Epoch 00008: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009524136, shape=(), dtype=float32).
# Epoch 8/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.6149 - dice_loss: 0.4764 - val_loss: 0.8681 - val_dice_loss: 0.7091 - lr: 9.5241e-04
#
# Epoch 00009: LearningRateScheduler reducing learning rate to tf.Tensor(0.00093815336, shape=(), dtype=float32).
# Epoch 9/50
# 240/240 [==============================] - 29s 122ms/step - loss: 0.5599 - dice_loss: 0.4323 - val_loss: 0.6640 - val_dice_loss: 0.5310 - lr: 9.3815e-04
#
# Epoch 00010: LearningRateScheduler reducing learning rate to tf.Tensor(0.000922164, shape=(), dtype=float32).
# Epoch 10/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.5197 - dice_loss: 0.4010 - val_loss: 0.8965 - val_dice_loss: 0.7410 - lr: 9.2216e-04
#
# Epoch 00011: LearningRateScheduler reducing learning rate to tf.Tensor(0.0009045085, shape=(), dtype=float32).
# Epoch 11/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.4844 - dice_loss: 0.3721 - val_loss: 0.7136 - val_dice_loss: 0.5780 - lr: 9.0451e-04
#
# Epoch 00012: LearningRateScheduler reducing learning rate to tf.Tensor(0.0008852567, shape=(), dtype=float32).
# Epoch 12/50
# 240/240 [==============================] - 30s 125ms/step - loss: 0.4390 - dice_loss: 0.3354 - val_loss: 0.4797 - val_dice_loss: 0.3716 - lr: 8.8526e-04
#
# Epoch 00013: LearningRateScheduler reducing learning rate to tf.Tensor(0.00086448435, shape=(), dtype=float32).
# Epoch 13/50
# 240/240 [==============================] - 29s 122ms/step - loss: 0.4254 - dice_loss: 0.3261 - val_loss: 0.5186 - val_dice_loss: 0.3898 - lr: 8.6448e-04
#
# Epoch 00014: LearningRateScheduler reducing learning rate to tf.Tensor(0.00084227364, shape=(), dtype=float32).
# Epoch 14/50
# 240/240 [==============================] - 31s 128ms/step - loss: 0.3890 - dice_loss: 0.2962 - val_loss: 0.4303 - val_dice_loss: 0.3319 - lr: 8.4227e-04
#
# Epoch 00015: LearningRateScheduler reducing learning rate to tf.Tensor(0.00081871205, shape=(), dtype=float32).
# Epoch 15/50
# 240/240 [==============================] - 30s 126ms/step - loss: 0.3600 - dice_loss: 0.2717 - val_loss: 0.4146 - val_dice_loss: 0.3206 - lr: 8.1871e-04
#
# Epoch 00016: LearningRateScheduler reducing learning rate to tf.Tensor(0.00079389266, shape=(), dtype=float32).
# Epoch 16/50
# 240/240 [==============================] - 29s 123ms/step - loss: 0.3318 - dice_loss: 0.2526 - val_loss: 0.3904 - val_dice_loss: 0.2874 - lr: 7.9389e-04
#
# Epoch 00017: LearningRateScheduler reducing learning rate to tf.Tensor(0.00076791336, shape=(), dtype=float32).
# Epoch 17/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.3023 - dice_loss: 0.2282 - val_loss: 0.5000 - val_dice_loss: 0.3947 - lr: 7.6791e-04
#
# Epoch 00018: LearningRateScheduler reducing learning rate to tf.Tensor(0.0007408768, shape=(), dtype=float32).
# Epoch 18/50
# 240/240 [==============================] - 30s 123ms/step - loss: 0.2700 - dice_loss: 0.2019 - val_loss: 0.3743 - val_dice_loss: 0.2727 - lr: 7.4088e-04
#
# Epoch 00019: LearningRateScheduler reducing learning rate to tf.Tensor(0.00071288965, shape=(), dtype=float32).
# Epoch 19/50
# 240/240 [==============================] - 30s 123ms/step - loss: 0.2541 - dice_loss: 0.1904 - val_loss: 0.3406 - val_dice_loss: 0.2665 - lr: 7.1289e-04
#
# Epoch 00020: LearningRateScheduler reducing learning rate to tf.Tensor(0.00068406225, shape=(), dtype=float32).
# Epoch 20/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.2603 - dice_loss: 0.1971 - val_loss: 0.4482 - val_dice_loss: 0.3186 - lr: 6.8406e-04
#
# Epoch 00021: LearningRateScheduler reducing learning rate to tf.Tensor(0.0006545085, shape=(), dtype=float32).
# Epoch 21/50
# 240/240 [==============================] - 30s 123ms/step - loss: 0.2368 - dice_loss: 0.1764 - val_loss: 0.3338 - val_dice_loss: 0.2562 - lr: 6.5451e-04
#
# Epoch 00022: LearningRateScheduler reducing learning rate to tf.Tensor(0.00062434503, shape=(), dtype=float32).
# Epoch 22/50
# 240/240 [==============================] - 29s 123ms/step - loss: 0.2189 - dice_loss: 0.1645 - val_loss: 0.2422 - val_dice_loss: 0.1824 - lr: 6.2435e-04
#
# Epoch 00023: LearningRateScheduler reducing learning rate to tf.Tensor(0.00059369067, shape=(), dtype=float32).
# Epoch 23/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.2059 - dice_loss: 0.1528 - val_loss: 0.2766 - val_dice_loss: 0.2068 - lr: 5.9369e-04
#
# Epoch 00024: LearningRateScheduler reducing learning rate to tf.Tensor(0.00056266657, shape=(), dtype=float32).
# Epoch 24/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.1937 - dice_loss: 0.1447 - val_loss: 0.2734 - val_dice_loss: 0.2081 - lr: 5.6267e-04
#
# Epoch 00025: LearningRateScheduler reducing learning rate to tf.Tensor(0.00053139526, shape=(), dtype=float32).
# Epoch 25/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.1872 - dice_loss: 0.1391 - val_loss: 0.2519 - val_dice_loss: 0.1919 - lr: 5.3140e-04
#
# Epoch 00026: LearningRateScheduler reducing learning rate to tf.Tensor(0.00049999997, shape=(), dtype=float32).
# Epoch 26/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.1674 - dice_loss: 0.1236 - val_loss: 0.2734 - val_dice_loss: 0.2084 - lr: 5.0000e-04
#
# Epoch 00027: LearningRateScheduler reducing learning rate to tf.Tensor(0.0004686048, shape=(), dtype=float32).
# Epoch 27/50
# 240/240 [==============================] - 30s 123ms/step - loss: 0.1535 - dice_loss: 0.1130 - val_loss: 0.1813 - val_dice_loss: 0.1359 - lr: 4.6860e-04
#
# Epoch 00028: LearningRateScheduler reducing learning rate to tf.Tensor(0.00043733336, shape=(), dtype=float32).
# Epoch 28/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.1531 - dice_loss: 0.1141 - val_loss: 0.2333 - val_dice_loss: 0.1750 - lr: 4.3733e-04
#
# Epoch 00029: LearningRateScheduler reducing learning rate to tf.Tensor(0.00040630935, shape=(), dtype=float32).
# Epoch 29/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.1456 - dice_loss: 0.1081 - val_loss: 0.2055 - val_dice_loss: 0.1564 - lr: 4.0631e-04
#
# Epoch 00030: LearningRateScheduler reducing learning rate to tf.Tensor(0.00037565507, shape=(), dtype=float32).
# Epoch 30/50
# 240/240 [==============================] - 30s 126ms/step - loss: 0.1384 - dice_loss: 0.1029 - val_loss: 0.1750 - val_dice_loss: 0.1330 - lr: 3.7566e-04
#
# Epoch 00031: LearningRateScheduler reducing learning rate to tf.Tensor(0.00034549143, shape=(), dtype=float32).
# Epoch 31/50
# 240/240 [==============================] - 29s 120ms/step - loss: 0.1335 - dice_loss: 0.0991 - val_loss: 0.2365 - val_dice_loss: 0.1830 - lr: 3.4549e-04
#
# Epoch 00032: LearningRateScheduler reducing learning rate to tf.Tensor(0.0003159377, shape=(), dtype=float32).
# Epoch 32/50
# 240/240 [==============================] - 29s 122ms/step - loss: 0.1342 - dice_loss: 0.0999 - val_loss: 0.1661 - val_dice_loss: 0.1255 - lr: 3.1594e-04
#
# Epoch 00033: LearningRateScheduler reducing learning rate to tf.Tensor(0.00028711034, shape=(), dtype=float32).
# Epoch 33/50
# 240/240 [==============================] - 29s 123ms/step - loss: 0.1184 - dice_loss: 0.0871 - val_loss: 0.1487 - val_dice_loss: 0.1110 - lr: 2.8711e-04
#
# Epoch 00034: LearningRateScheduler reducing learning rate to tf.Tensor(0.0002591231, shape=(), dtype=float32).
# Epoch 34/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.1144 - dice_loss: 0.0849 - val_loss: 0.1558 - val_dice_loss: 0.1169 - lr: 2.5912e-04
#
# Epoch 00035: LearningRateScheduler reducing learning rate to tf.Tensor(0.00023208655, shape=(), dtype=float32).
# Epoch 35/50
# 240/240 [==============================] - 30s 123ms/step - loss: 0.1121 - dice_loss: 0.0835 - val_loss: 0.1392 - val_dice_loss: 0.1054 - lr: 2.3209e-04
#
# Epoch 00036: LearningRateScheduler reducing learning rate to tf.Tensor(0.00020610739, shape=(), dtype=float32).
# Epoch 36/50
# 240/240 [==============================] - 29s 122ms/step - loss: 0.1090 - dice_loss: 0.0805 - val_loss: 0.1379 - val_dice_loss: 0.1042 - lr: 2.0611e-04
#
# Epoch 00037: LearningRateScheduler reducing learning rate to tf.Tensor(0.00018128792, shape=(), dtype=float32).
# Epoch 37/50
# 240/240 [==============================] - 30s 123ms/step - loss: 0.1050 - dice_loss: 0.0781 - val_loss: 0.1345 - val_dice_loss: 0.1016 - lr: 1.8129e-04
#
# Epoch 00038: LearningRateScheduler reducing learning rate to tf.Tensor(0.00015772645, shape=(), dtype=float32).
# Epoch 38/50
# 240/240 [==============================] - 29s 123ms/step - loss: 0.0956 - dice_loss: 0.0702 - val_loss: 0.1286 - val_dice_loss: 0.0957 - lr: 1.5773e-04
#
# Epoch 00039: LearningRateScheduler reducing learning rate to tf.Tensor(0.0001355157, shape=(), dtype=float32).
# Epoch 39/50
# 240/240 [==============================] - 29s 123ms/step - loss: 0.0999 - dice_loss: 0.0750 - val_loss: 0.1172 - val_dice_loss: 0.0877 - lr: 1.3552e-04
#
# Epoch 00040: LearningRateScheduler reducing learning rate to tf.Tensor(0.00011474339, shape=(), dtype=float32).
# Epoch 40/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.0986 - dice_loss: 0.0732 - val_loss: 0.1202 - val_dice_loss: 0.0894 - lr: 1.1474e-04
#
# Epoch 00041: LearningRateScheduler reducing learning rate to tf.Tensor(9.54915e-05, shape=(), dtype=float32).
# Epoch 41/50
# 240/240 [==============================] - 30s 123ms/step - loss: 0.0981 - dice_loss: 0.0735 - val_loss: 0.1142 - val_dice_loss: 0.0852 - lr: 9.5492e-05
#
# Epoch 00042: LearningRateScheduler reducing learning rate to tf.Tensor(7.783601e-05, shape=(), dtype=float32).
# Epoch 42/50
# 240/240 [==============================] - 29s 123ms/step - loss: 0.0889 - dice_loss: 0.0661 - val_loss: 0.1180 - val_dice_loss: 0.0884 - lr: 7.7836e-05
#
# Epoch 00043: LearningRateScheduler reducing learning rate to tf.Tensor(6.184671e-05, shape=(), dtype=float32).
# Epoch 43/50
# 240/240 [==============================] - 30s 127ms/step - loss: 0.0899 - dice_loss: 0.0673 - val_loss: 0.1085 - val_dice_loss: 0.0807 - lr: 6.1847e-05
#
# Epoch 00044: LearningRateScheduler reducing learning rate to tf.Tensor(4.7586444e-05, shape=(), dtype=float32).
# Epoch 44/50
# 240/240 [==============================] - 30s 126ms/step - loss: 0.0851 - dice_loss: 0.0636 - val_loss: 0.1055 - val_dice_loss: 0.0788 - lr: 4.7586e-05
#
# Epoch 00045: LearningRateScheduler reducing learning rate to tf.Tensor(3.5111727e-05, shape=(), dtype=float32).
# Epoch 45/50
# 240/240 [==============================] - 29s 123ms/step - loss: 0.0883 - dice_loss: 0.0663 - val_loss: 0.1090 - val_dice_loss: 0.0816 - lr: 3.5112e-05
#
# Epoch 00046: LearningRateScheduler reducing learning rate to tf.Tensor(2.4471761e-05, shape=(), dtype=float32).
# Epoch 46/50
# 240/240 [==============================] - 29s 122ms/step - loss: 0.0803 - dice_loss: 0.0592 - val_loss: 0.1076 - val_dice_loss: 0.0806 - lr: 2.4472e-05
#
# Epoch 00047: LearningRateScheduler reducing learning rate to tf.Tensor(1.5708387e-05, shape=(), dtype=float32).
# Epoch 47/50
# 240/240 [==============================] - 29s 121ms/step - loss: 0.0858 - dice_loss: 0.0643 - val_loss: 0.1064 - val_dice_loss: 0.0796 - lr: 1.5708e-05
#
# Epoch 00048: LearningRateScheduler reducing learning rate to tf.Tensor(8.856387e-06, shape=(), dtype=float32).
# Epoch 48/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.0834 - dice_loss: 0.0622 - val_loss: 0.1069 - val_dice_loss: 0.0800 - lr: 8.8564e-06
#
# Epoch 00049: LearningRateScheduler reducing learning rate to tf.Tensor(3.9426386e-06, shape=(), dtype=float32).
# Epoch 49/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.0824 - dice_loss: 0.0610 - val_loss: 0.1059 - val_dice_loss: 0.0792 - lr: 3.9426e-06
#
# Epoch 00050: LearningRateScheduler reducing learning rate to tf.Tensor(9.866358e-07, shape=(), dtype=float32).
# Epoch 50/50
# 240/240 [==============================] - 29s 119ms/step - loss: 0.0808 - dice_loss: 0.0596 - val_loss: 0.1062 - val_dice_loss: 0.0794 - lr: 9.8664e-07

# %%
dice_loss = history.history['dice_loss']
loss = history.history['loss']
val_dice_loss = history.history['val_dice_loss']
val_loss = history.history['val_loss']

epochs_range = range(max_epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, loss, label='Loss')
plt.plot(epochs_range, dice_loss, label='Dice Loss')
plt.legend(loc='upper right')
plt.title('Train Loss')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, val_loss, label='Val Loss')
plt.plot(epochs_range, val_dice_loss, label='Val Dice Loss')
plt.legend(loc='upper right')
plt.title('Valid Loss')
plt.show()

# %%
print_images()

# %%
# restoring the latest checkpoint in checkpoint_dir
model.load_weights(checkpoint_dir)

# %%
def mean_iou(y_true, y_pred, num_classes=2):
    # Flatten  
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])

    y_true_f = tf.cast(tf.round(y_true_f), dtype=tf.int32).numpy()
    y_pred_f = tf.cast(tf.round(y_pred_f), dtype=tf.int32).numpy()

    # calculate confusion matrix
    labels = list(range(num_classes))
    current = confusion_matrix(y_true_f, y_pred_f, labels=labels)

    # compute mean iou
    intersection = np.diag(current)
    ground_truth_set = current.sum(axis=1)
    predicted_set = current.sum(axis=0)
    union = ground_truth_set + predicted_set - intersection

    IoU = intersection / union.astype(np.float32)
    return np.mean(IoU)

# %%
mean = []

for images, labels in test_dataset:
    predictions = model(images, training=False)
    m = mean_iou(labels, predictions)
    mean.append(m)

mean = np.array(mean)
mean = np.mean(mean)
print("mean_iou: {}".format(mean))
# Out:
# mean_iou: 0.905902157412941

# %% [markdown]
# ##### 실험 결과 : UNet < encoder-decoder < pretrained UNet
# ##### UNet 과 encoder-decoder 성능이 비슷하게 나왔는데 데이터 수가 적은 편이라 모든 상황에 해당된다고 말하기는 어려울 것 같다.
